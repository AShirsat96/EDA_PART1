# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing data from csv and using .name for naming data frame
df2017= pd.read_csv('WorldHappiness_2017.csv')
df2017.name ='df_2017'
df2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df2018= pd.read_csv('WorldHappiness_2018.csv')
df2018.name ='df_2018'
df2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df2019= pd.read_csv('WorldHappiness_2019.csv')
df2019.name ='df_2019'
df2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Writing a for loop to determine the number of rows and columns for all the three data frames
for x in (df2017,df2018,df2019):
    print(x.name, ' ' , x.shape)
# Out:
# df_2017   (155, 12)
# df_2018   (156, 9)
# df_2019   (156, 9)

# %%
# Using .info to find out total elements for each column and its data type.
df2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# Using .columns to find out the name of columns
df2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
# Renaming columns using .rename({},axis = 1,inplace=True)
df2017.rename({'Happiness.Rank':'Rank','Happiness.Score':'Score'},axis=1,inplace=True)
df2017.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Whisker.high', 'Whisker.low',
#        'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.',
#        'Freedom', 'Generosity', 'Trust..Government.Corruption.',
#        'Dystopia.Residual'],
#       dtype='object')

# %%
df2017.rename({'Economy..GDP.per.Capita.':'GDP_per_capita','Family':'Social_support', 'Health..Life.Expectancy.':'Health_Life_Expectancy','Trust..Government.Corruption.':'Corruption'},axis=1,inplace=True)
df2017.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'Whisker.high', 'Whisker.low',
#        'GDP_per_capita', 'Social_support', 'Health_Life_Expectancy', 'Freedom',
#        'Generosity', 'Corruption', 'Dystopia.Residual'],
#       dtype='object')

# %%
# Using .pop to delete columns permanently from the data frame.
df2017.pop('Dystopia.Residual')
# Out:
# 0      2.277027
# 1      2.313707
# 2      2.322715
# 3      2.276716
# 4      2.430182
#          ...
# 150    0.540061
# 151    1.061574
# 152    0.621130
# 153    1.683024
# 154    2.066005
# Name: Dystopia.Residual, Length: 155, dtype: float64

# %%
df2017.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df2018.rename({'Overall rank':'Rank', 'Country or region':'Country','GDP per capita':'GDP_per_capita', 'Social support': 'Social_support','Healthy life expectancy':'Health_Life_Expectancy'},axis=1,inplace=True)
df2018.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df2018.rename({'Freedom to make life choices':'Freedom', 'Perceptions of corruption':'Corruption'},axis=1,inplace=True)
df2018.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df2019.rename({'Overall rank':'Rank', 'Country or region':'Country','GDP per capita':'GDP_per_capita', 'Social support': 'Social_support','Healthy life expectancy':'Health_Life_Expectancy','Freedom to make life choices':'Freedom', 'Perceptions of corruption':'Corruption'},axis=1,inplace=True)
df2019.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df2017.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df2017 = df2017.reindex(columns=['Rank', 'Country', 'Score', 'GDP_per_capita', 'Social_support',
       'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'])

# %%
df2017.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_per_capita', 'Social_support',
#        'Health_Life_Expectancy', 'Freedom', 'Generosity', 'Corruption'],
#       dtype='object')

# %%
df2017.sample(5)
# Out:
#      Rank      Country  Score  GDP_per_capita  Social_support  \
# 148   149       Guinea  3.507        0.244550        0.791245
# 44     45  El Salvador  6.003        0.909784        1.182125
# 107   108         Iran  4.692        1.156873        0.711551
# 59     60   Kazakhstan  5.819        1.284556        1.384369
# 128   129     Cambodia  4.168        0.601765        1.006238
#
#      Health_Life_Expectancy   Freedom  Generosity  Corruption
# 148                0.194129  0.348588    0.264815    0.110938
# 44                 0.596019  0.432453    0.078258    0.089981
# 107                0.639333  0.249323    0.387243    0.048761
# 59                 0.606042  0.437454    0.201964    0.119283
# 128                0.429783  0.633376    0.385923    0.068106

# %%
df2018.sample(5)
# Out:
#      Rank     Country  Score  GDP_per_capita  Social_support  \
# 96     97      Bhutan  5.082           0.796           1.335
# 12     13  Costa Rica  7.072           1.010           1.459
# 122   123  Mozambique  4.417           0.198           0.902
# 87     88  Tajikistan  5.199           0.474           1.166
# 35     36       Spain  6.310           1.251           1.538
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 96                    0.527    0.541       0.364       0.171
# 12                    0.817    0.632       0.143       0.101
# 122                   0.173    0.531       0.206       0.158
# 87                    0.598    0.292       0.187       0.034
# 35                    0.965    0.449       0.142       0.074

# %%
df2019.sample(5)
# Out:
#      Rank        Country  Score  GDP_per_capita  Social_support  \
# 140   141        Liberia  3.975           0.073           0.922
# 73     74     Tajikistan  5.467           0.493           1.098
# 18     19  United States  6.892           1.433           1.457
# 122   123     Mozambique  4.466           0.204           0.986
# 107   108      Venezuela  4.707           0.960           1.427
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 140                   0.443    0.370       0.233       0.033
# 73                    0.718    0.389       0.230       0.144
# 18                    0.874    0.454       0.280       0.128
# 122                   0.390    0.494       0.197       0.138
# 107                   0.805    0.154       0.064       0.047

# %%
df2017.insert(0, "Year", 2017, True)

# %%
df2017.sample(5)
# Out:
#      Year  Rank                 Country  Score  GDP_per_capita  \
# 101  2017   102                 Tunisia  4.805        1.007266
# 45   2017    46                  Poland  5.973        1.291788
# 47   2017    48                   Italy  5.964        1.395067
# 107  2017   108                    Iran  4.692        1.156873
# 89   2017    90  Bosnia and Herzegovina  5.182        0.982409
#
#      Social_support  Health_Life_Expectancy   Freedom  Generosity  Corruption
# 101        0.868351                0.613212  0.289681    0.049693    0.086723
# 45         1.445712                0.699475  0.520342    0.158466    0.059308
# 47         1.444923                0.853144  0.256451    0.172790    0.028028
# 107        0.711551                0.639333  0.249323    0.387243    0.048761
# 89         1.069336                0.705186  0.204403    0.328867    0.000000

# %%
df2018.insert(0, "Year", 2018, True)
df2019.insert(0, "Year", 2019, True)

# %%
df2018.sample(5)
# Out:
#      Year  Rank     Country  Score  GDP_per_capita  Social_support  \
# 12   2018    13  Costa Rica  7.072           1.010           1.459
# 36   2018    37    Colombia  6.260           0.960           1.439
# 63   2018    64    Paraguay  5.681           0.835           1.522
# 125  2018   126  Mauritania  4.356           0.557           1.245
# 72   2018    73     Belarus  5.483           1.039           1.498
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 12                    0.817    0.632       0.143       0.101
# 36                    0.635    0.531       0.099       0.039
# 63                    0.615    0.541       0.162       0.074
# 125                   0.292    0.129       0.134       0.093
# 72                    0.700    0.307       0.101       0.154

# %%
df2019.sample(5)
# Out:
#      Year  Rank       Country  Score  GDP_per_capita  Social_support  \
# 114  2019   115  Burkina Faso  4.587           0.331           1.056
# 115  2019   116       Armenia  4.559           0.850           1.055
# 122  2019   123    Mozambique  4.466           0.204           0.986
# 52   2019    53        Latvia  5.940           1.187           1.465
# 134  2019   135     Swaziland  4.212           0.811           1.149
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 114                   0.380    0.255       0.177       0.113
# 115                   0.815    0.283       0.095       0.064
# 122                   0.390    0.494       0.197       0.138
# 52                    0.812    0.264       0.075       0.064
# 134                   0.000    0.313       0.074       0.135

# %%
# Get top ten most generous countries in 2017,2018 and 2019
df2017_generous=df2017.sort_values('Generosity',ascending=False).head(10)
df2017_generous
# Out:
#      Year  Rank         Country  Score  GDP_per_capita  Social_support  \
# 113  2017   114         Myanmar  4.545        0.367111        1.123236
# 80   2017    81       Indonesia  5.262        0.995539        1.274445
# 26   2017    27           Malta  6.527        1.343280        1.488412
# 31   2017    32        Thailand  6.424        1.127869        1.425792
# 7    2017     8     New Zealand  7.314        1.405706        1.548195
# 151  2017   152           Syria  3.462        0.777153        0.396103
# 18   2017    19  United Kingdom  6.714        1.441634        1.496460
# 119  2017   120       Sri Lanka  4.440        1.009850        1.259976
# 144  2017   145           Haiti  3.603        0.368610        0.640450
# 9    2017    10       Australia  7.284        1.484415        1.510042
#
#      Health_Life_Expectancy   Freedom  Generosity  Corruption
# 113                0.397523  0.514492    0.838075    0.188816
# 80                 0.492346  0.443323    0.611705    0.015317
# ...

# %%
df2017_generous
# Out:
#      Year  Rank      Country  Score  GDP_per_capita  Social_support  \
# 113  2017   114      Myanmar  4.545        0.367111        1.123236
# 80   2017    81    Indonesia  5.262        0.995539        1.274445
# 26   2017    27        Malta  6.527        1.343280        1.488412
# 31   2017    32     Thailand  6.424        1.127869        1.425792
# 7    2017     8  New Zealand  7.314        1.405706        1.548195
# ..    ...   ...          ...    ...             ...             ...
# 117  2017   118        Gabon  4.465        1.198210        1.155620
# 83   2017    84      Morocco  5.235        0.878115        0.774864
# 78   2017    79        China  5.273        1.081166        1.160837
# 51   2017    52    Lithuania  5.902        1.314582        1.473516
# 86   2017    87       Greece  5.227        1.289487        1.239415
#
#      Health_Life_Expectancy   Freedom  Generosity  Corruption
# 113                0.397523  0.514492    0.838075    0.188816
# ...

# %%
df2018_generous=df2018.sort_values('Generosity',ascending=False).head(10)
df2018_generous
# Out:
#      Year  Rank      Country  Score  GDP_per_capita  Social_support  \
# 129  2018   130      Myanmar  4.308           0.682           1.174
# 95   2018    96    Indonesia  5.093           0.899           1.215
# 147  2018   148        Haiti  3.582           0.315           0.714
# 149  2018   150        Syria  3.462           0.689           0.382
# 21   2018    22        Malta  6.627           1.270           1.525
# 7    2018     8  New Zealand  7.324           1.268           1.601
# 45   2018    46     Thailand  6.072           1.016           1.417
# 96   2018    97       Bhutan  5.082           0.796           1.335
# 9    2018    10    Australia  7.272           1.340           1.573
# 18   2018    19       Israel  6.814           1.301           1.559
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 129                   0.429    0.580       0.598       0.178
# 95                    0.522    0.538       0.484       0.018
# ...

# %%
df2018_generous
# Out:
#      Year  Rank      Country  Score  GDP_per_capita  Social_support  \
# 129  2018   130      Myanmar  4.308           0.682           1.174
# 95   2018    96    Indonesia  5.093           0.899           1.215
# 147  2018   148        Haiti  3.582           0.315           0.714
# 149  2018   150        Syria  3.462           0.689           0.382
# 21   2018    22        Malta  6.627           1.270           1.525
# 7    2018     8  New Zealand  7.324           1.268           1.601
# 45   2018    46     Thailand  6.072           1.016           1.417
# 96   2018    97       Bhutan  5.082           0.796           1.335
# 9    2018    10    Australia  7.272           1.340           1.573
# 18   2018    19       Israel  6.814           1.301           1.559
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 129                   0.429    0.580       0.598       0.178
# 95                    0.522    0.538       0.484       0.018
# ...

# %%
df2019_generous=df2019.sort_values('Generosity',ascending=False).head(10)
df2019_generous
# Out:
#      Year  Rank         Country  Score  GDP_per_capita  Social_support  \
# 130  2019   131         Myanmar  4.360           0.710           1.181
# 91   2019    92       Indonesia  5.192           0.931           1.203
# 146  2019   147           Haiti  3.597           0.323           0.688
# 21   2019    22           Malta  6.726           1.300           1.520
# 120  2019   121           Kenya  4.509           0.512           0.983
# 94   2019    95          Bhutan  5.082           0.813           1.321
# 51   2019    52        Thailand  6.008           1.050           1.409
# 3    2019     4         Iceland  7.494           1.380           1.624
# 14   2019    15  United Kingdom  7.054           1.333           1.538
# 10   2019    11       Australia  7.228           1.372           1.548
#
#      Health_Life_Expectancy  Freedom  Generosity  Corruption
# 130                   0.555    0.525       0.566       0.172
# 91                    0.660    0.491       0.498       0.028
# ...

# %%
# Get data for generous countries common in all three years.
dfgenerous=df2017_generous.merge(df2018_generous,on="Country",how="inner")
dfgenerous
# Out:
#    Year_x  Rank_x      Country  Score_x  GDP_per_capita_x  Social_support_x  \
# 0    2017     114      Myanmar    4.545          0.367111          1.123236
# 1    2017      81    Indonesia    5.262          0.995539          1.274445
# 2    2017      27        Malta    6.527          1.343280          1.488412
# 3    2017      32     Thailand    6.424          1.127869          1.425792
# 4    2017       8  New Zealand    7.314          1.405706          1.548195
# 5    2017     152        Syria    3.462          0.777153          0.396103
# 6    2017     145        Haiti    3.603          0.368610          0.640450
# 7    2017      10    Australia    7.284          1.484415          1.510042
#
#    Health_Life_Expectancy_x  Freedom_x  Generosity_x  Corruption_x  Year_y  \
# 0                  0.397523   0.514492      0.838075      0.188816    2018
# 1                  0.492346   0.443323      0.611705      0.015317    2018
# ...

# %%
dfgenerous2=dfgenerous.merge(df2019_generous,on="Country",how="inner")
dfgenerous2
# Out:
#    Year_x  Rank_x    Country  Score_x  GDP_per_capita_x  Social_support_x  \
# 0    2017     114    Myanmar    4.545          0.367111          1.123236
# 1    2017      81  Indonesia    5.262          0.995539          1.274445
# 2    2017      27      Malta    6.527          1.343280          1.488412
# 3    2017      32   Thailand    6.424          1.127869          1.425792
# 4    2017     145      Haiti    3.603          0.368610          0.640450
# 5    2017      10  Australia    7.284          1.484415          1.510042
#
#    Health_Life_Expectancy_x  Freedom_x  Generosity_x  Corruption_x  ...  \
# 0                  0.397523   0.514492      0.838075      0.188816  ...
# 1                  0.492346   0.443323      0.611705      0.015317  ...
# 2                  0.821944   0.588767      0.574731      0.153066  ...
# 3                  0.647239   0.580201      0.572123      0.031613  ...
# 4                  0.277321   0.030370      0.489204      0.099872  ...
# ...

# %%
df3=dfgenerous2[['Country','Generosity_x','Generosity_y','Generosity']]
df3
df3.to_csv('Three_Years_Top_Generous.csv')
df3.to_excel('Three_Years_Top_Generous.xlsx')

# %%
dfgenerous2[['Country','Generosity_x','Generosity_y','Generosity']].to_csv('test.csv')
